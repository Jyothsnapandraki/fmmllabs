# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothsnapandraki/fmmllabs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 16:42:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   196MB/s    in 0.4s
#
# 2024-03-31 16:42:37 (196 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5584    1303.6746v4  We address the problem of finding the maximize...  stat
# 5167    1102.3949v2  We address the sparse signal recovery problem ...  stat
# 28332  1706.02425v1  In this paper, we investigated a C-arm tomogra...    cs
# 4772    1410.5557v1  Goals express agents' intentions and allow the...    cs
# 32955  1511.06747v4  We propose a unified framework for neural net ...    cs
# ...             ...                                                ...   ...
# 13418   1209.4855v1  The paper describes some recent developments i...    cs
# 5421    1210.1960v1  Feature selection is a technique to screen out...  stat
# 6107   1607.05047v1  We develop an off-policy actor-critic algorith...  stat
# 38818  1505.03566v2  Extracting moving objects from a video sequenc...    cs
# 21726   1210.3335v3  Graph clustering involves the task of dividing...  stat
#
#                                                    title  year  \
# 5584   Exploiting correlation and budget constraints ...  2013
# 5167   Sparse Signal Recovery with Temporally Correla...  2011
# 28332  C-arm Tomographic Imaging Technique for Nephro...  2017
# 4772   Where do goals come from? A Generic Approach t...  2014
# 32955  Data-Dependent Path Normalization in Neural Ne...  2015
# ...                                                  ...   ...
# 13418                      The Future of Neural Networks  2012
# 5421   Feature Selection via L1-Penalized Squared-Los...  2012
# 6107   A Batch, Off-Policy, Actor-Critic Algorithm fo...  2016
# 38818  COROLA: A Sequential Solution to Moving Object...  2015
# 21726                          Improved Graph Clustering  2012
#
#                                                 keywords
# 5584   [maximizer, nonlinear, evaluated, constraints,...
# 5167   [measurement, temporally, correlated, algorith...
# 28332  [investigated, tomographic, technique, dimensi...
# 4772   [intentions, dimensional, abstractions, dimens...
# 32955  [framework, normalization, regularization, opt...
# ...                                                  ...
# 13418  [describes, developments, discusses, applicabi...
# 5421   [selection, technique, important, supervised, ...
# 6107   [algorithm, individuals, algorithm, developed,...
# 38818  [extracting, estimating, background, individua...
# 21726  [clustering, statistical, evaluating, solution...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5584     [maximizer, nonlinear, evaluated, constraints,...
# 5167     [measurement, temporally, correlated, algorith...
# 28332    [investigated, tomographic, technique, dimensi...
# 4772     [intentions, dimensional, abstractions, dimens...
# 32955    [framework, normalization, regularization, opt...
#                                ...
# 30618    [detection, availability, detectors, important...
# 38099    [challenge, annotation, biological, databases,...
# 33610    [understanding, complexity, evolutionary, algo...
# 36453    [surprisingly, concentrated, individuals, stat...
# 4825     [difference, reinforcement, performance, compu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8778 words.
# Out of those 4534 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1c4ccc0c-77d0-48fc-a9fe-e446231739a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c4ccc0c-77d0-48fc-a9fe-e446231739a9")) {                    Plotly.newPlot(                        "1c4ccc0c-77d0-48fc-a9fe-e446231739a9",                        [{"x":["literature","comprehensive","evaluated","approaches","identification","modelling","exploiting","techniques","introduce","including","correlation","applications","comparison","correlations","constraints","automatic","frequentist","different","evaluation","toolboxes","counterpart","evaluations","optimization","practical","situations","classical","nonlinear","outperforms","empirically","permitted","comparisons","desirable","experiments","algorithms","correlated","significantly","interesting","especially","theoretical","framework","measurement","performance","furthermore","extensive","temporally","underdetermined","information","technique","performed","maximization","projection","simultaneous","simulated","reconstruction","experimental","developed","identifiable","capability","spherical","radiation","algebraic","investigated","simulation","preliminary","tomographic","expectation","dimensional","detection","reconstructed","likelihood","demonstrated","intention","computational","explained","autonomous","formulation","development","intentions","dimensionality","alongside","conceptual","mechanisms","constitute","longstanding","developmental","considered","autonomously","representations","effective","reinforcement","abstractions","reduction","investigate","dependence","gradients","regularization","connection","dependent","normalization","invariance","interpolates","dimensions","disadvantages","multivariate","sequences","distributions","variables","transport","clustering","advantages","distances","reproducible","leverages","methodology","implementation","described","structure","financial","divergences","enhancement","presented","algorithm","imperfect","classification","procedure","repairing","increasing","important","restricted","invariant","contributions","performing","retrieval","boltzmann","extracted","convolutional","computation","transformations","arbitrary","incorporate","consistently","computing","descriptors","throughout","specifically","empirical","outstanding","invariances","mathematical","translation","compensate","underlying","complicated","informative","application","unlabeled","initially","predicting","knowledge","uncertainty","generating","challenges","interacting","collected","utterances","combining","telephone","insufficient","programming","regression","separation","available","simulations","numerical","interface","potential","programmers","inefficient","conducted","effectiveness","coordinate","solutions","accelerated","challenge","favorable","iteration","complexity","qualities","obtaining","particularly","convergence","dimension","positivity","resulting","considering","alternative","statistics","operations","histograms","intractable"],"y":[122,61,136,416,96,45,72,395,312,250,70,461,133,29,154,166,0,720,249,1,20,65,309,148,61,106,59,245,68,1,29,31,588,599,31,279,58,128,150,526,34,856,155,178,20,0,674,219,125,33,55,28,56,101,379,196,1,44,8,6,20,40,64,56,4,36,162,354,20,56,102,9,315,16,49,88,129,7,47,6,20,58,14,6,7,127,12,244,229,118,9,95,145,29,32,83,47,69,32,19,2,49,9,28,111,112,129,5,131,102,28,3,37,68,131,77,340,11,5,32,164,810,9,477,116,3,104,346,64,50,43,73,121,21,100,380,139,40,82,65,43,134,35,28,168,150,8,1,51,117,8,133,29,31,249,45,22,88,361,89,103,124,16,73,12,104,3,10,140,123,32,303,42,81,22,157,7,13,80,216,24,148,10,151,10,38,238,5,46,85,111,66,2,161,65,94,56,71,7,29],"type":"bar"},{"x":["literature","comprehensive","evaluated","approaches","identifi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4534,), (4534, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8258333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <span style=''>based</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.828125);'>Translation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>based</span> <span style=''>learning</span> <span style=''>(EBL)</span> <span style=''>in</span> <span style=''>the</span> <span style=''>parsing</span> <span style=''>module</span> <span style=''>of</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>English</span> <span style=''>Spanish</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.828125);'>translation</span> <span style=''>system</span> <span style=''>designed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>translate</span> <span style=''>closed</span> <span style=''>captions</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>efficiencycoverage</span> <span style=''>trade</span> <span style=''>offs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>EBL</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>we</span> <span style=''>use</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>coverage</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>of</span> <span style=''>space</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Porcupine</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(Almost)</span> <span style=''>All</span> <span style=''>Local</span> <span style=''>Optima</span> <span style=''>are</span> <span style=''>Global</span> <br/><br/><span style=''>Neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prominently</span> <span style=''>in</span> <span style=''>several</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>In</span> <span style=''>general</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>take</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>asking</span> <span style=''>whether</span> <span style=''>one</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrain</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>weights</span> <span style=''>to</span> <span style=''>make</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>landscape</span> <span style=''>have</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>while</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>be</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unconstrained</span> <span style=''>one</span> <span style=''>For</span> <span style=''>two</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>affirmative</span> <span style=''>answers</span> <span style=''>to</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>Porcupine</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(PNNs)</span> <span style=''>whose</span> <span style=''>weight</span> <span style=''>vectors</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>to</span> <span style=''>lie</span> <span style=''>over</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>lines</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>most</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomial</span> <span style='background-color:rgba(255, 0, 0, 0.30573248407643305);'>Approximation</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>semi</span> <span style=''>agnostic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636364);'>univariate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.34117647058823525);'>distributions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>Let</span> <span style=''>p</span> <span style=''>be</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(255, 0, 0, 0.32103321033210325);'>distribution</span> <span style=''>over</span> <span style=''>an</span> <span style=''>interval</span> <span style=''>I</span> <span style=''>which</span> <span style=''>is</span> <span style=''>tau</span> <span style=''>close</span> <span style=''>(in</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>distance)</span> <span style=''>to</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.32103321033210325);'>distribution</span> <span style=''>q</span> <span style=''>that</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>of</span> <span style=''>I</span> <span style=''>into</span> <span style=''>t</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervals</span> <span style=''>and</span> <span style=''>t</span> <span style=''>unknown</span> <span style=''>degree</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomials</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifying</span> <span style=''>q</span> <span style=''>over</span> <span style=''>each</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervals</span> <span style=''>We</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>draws</span> <span style=''>tildeO(tnew(d1)eps2)</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>p</span> <span style=''>runs</span> <span style=''>in</span> <span style=''>time</span> <span style=''>poly(td1eps)</span> <span style=''>and</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>outputs</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>of</span> <span style=''>Human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cognition</span> <span style=''>across</span> <span style=''>Many</span> <span style=''>fMRI</span> <span style=''>Studies</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Cognitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroscience</span> <span style=''>is</span> <span style=''>enjoying</span> <span style=''>rapid</span> <span style=''>increase</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style=''>public</span> <span style=''>brain</span> <span style=''>imaging</span> <span style=''>datasets</span> <span style=''>It</span> <span style=''>opens</span> <span style=''>the</span> <span style=''>door</span> <span style=''>to</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>Finding</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>data</span> <span style=''>calls</span> <span style=''>for</span> <span style=''>scalable</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>to</span> <span style=''>an</span> <span style=''>old</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>brain</span> <span style=''>function</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognitive</span> <span style=''>system</span> <span style=''>that</span> <span style=''>relates</span> <span style=''>mental</span> <span style=''>operationscognitive</span> <span style=''>processespsychological</span> <span style=''>tasks</span> <span style=''>to</span> <span style=''>brain</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>cast</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>brain</span> <span style=''>maps</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>studies</span> <span style=''>For</span> <span style=''>this</span> <span style=''>we</span> <span style=''>leverage</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05079928952042629)
# 	information (0.2394316163410302)
# 	segmentation (0.06714031971580817)
# 	knowledge (0.12824156305506218)
# 	experimental (0.13463587921847248)
# 	representation (0.14031971580817051)
# 	different (0.2557726465364121)
# 	detection (0.12575488454706926)
# 	recognition (0.1236234458259325)
# 	convolutional (0.1349911190053286)
#
# Some Statistics words are:
# 	variables (0.12997481108312342)
# 	stochastic (0.13299748110831233)
# 	statistical (0.15365239294710328)
# 	algorithm (0.3848866498740554)
# 	theoretical (0.15062972292191434)
# 	inference (0.19093198992443325)
# 	estimation (0.1778337531486146)
# 	distribution (0.18035264483627203)
# 	dimensional (0.18387909319899245)
# 	regression (0.18287153652392948)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3502e27f-4701-41db-b378-aa8ba6bb9d4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3502e27f-4701-41db-b378-aa8ba6bb9d4e")) {                    Plotly.newPlot(                        "3502e27f-4701-41db-b378-aa8ba6bb9d4e",                        [{"x":["literature","comprehensive","evaluated","approaches","identification","modelling","exploiting","techniques","introduce","including","correlation","applications","comparison","correlations","constraints","automatic","frequentist","different","evaluation","toolboxes","counterpart","evaluations","optimization","practical","situations","classical","nonlinear","outperforms","empirically","permitted","comparisons","desirable","experiments","algorithms","correlated","significantly","interesting","especially","theoretical","framework","measurement","performance","furthermore","extensive","temporally","underdetermined","information","technique","performed","maximization","projection","simultaneous","simulated","reconstruction","experimental","developed","identifiable","capability","spherical","radiation","algebraic","investigated","simulation","preliminary","tomographic","expectation","dimensional","detection","reconstructed","likelihood","demonstrated","intention","computational","explained","autonomous","formulation","development","intentions","dimensionality","alongside","conceptual","mechanisms","constitute","longstanding","developmental","considered","autonomously","representations","effective","reinforcement","abstractions","reduction","investigate","dependence","gradients","regularization","connection","dependent","normalization","invariance","interpolates","dimensions","disadvantages","multivariate","sequences","distributions","variables","transport","clustering","advantages","distances","reproducible","leverages","methodology","implementation","described","structure","financial","divergences","enhancement","presented","algorithm","imperfect","classification","procedure","repairing","increasing","important","restricted","invariant","contributions","performing","retrieval","boltzmann","extracted","convolutional","computation","transformations","arbitrary","incorporate","consistently","computing","descriptors","throughout","specifically","empirical","outstanding","invariances","mathematical","translation","compensate","underlying","complicated","informative","application","unlabeled","initially","predicting","knowledge","uncertainty","generating","challenges","interacting","collected","utterances","combining","telephone","insufficient","programming","regression","separation","available","simulations","numerical","interface","potential","programmers","inefficient","conducted","effectiveness","coordinate","solutions","accelerated","challenge","favorable","iteration","complexity","qualities","obtaining","particularly","convergence","dimension","positivity","resulting","considering","alternative","statistics","operations","histograms","intractable","transportation","parameter","significant","characteristic","estimated","operating","unsupervised","precision","sufficient","aggregating","accurately","discriminate","extending","drawbacks","generally","supervised","recognising","recognition","exceeding","variations","filtering","demonstrate","automated","benchmarks","illumination","excitation","identities","downloaded","particular","extensively","optimizing","corresponding","sensitive","stochastic","estimator","controller","conditional","prominent","sketching","relationship","randomized","difficult","standpoint","bootstrap","typically","precisely","ingredient","multiplication","extrapolation","estimating","estimation","addressing","essential","computations","accelerates","conseq ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	frequentist
# 	underdetermined
# 	barycenters
# 	kantorovich
# 	blockwise
# 	periodicity
# 	statistician
# 	explodingvanishing
# 	misspecified
# 	semiparametric
# 	functionals
# 	nomination
# 	bernstein
# 	unweighted
# 	dendrogram
# 	recasting
# 	hyperpriors
# 	encapsulated
# 	faithfulness
# 	compromises
# Some words which never appear in Statistics papers:
# 	tomographic
# 	developmental
# 	autonomously
# 	imperfect
# 	repairing
# 	telephone
# 	programmers
# 	recognising
# 	excitation
# 	conversational
# 	conversation
# 	idiosyncrasies
# 	gazetteer
# 	punctuation
# 	duplicate
# 	modularized
# 	occlusions
# 	holographic
# 	labelling
# 	subsystem

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0596010280259455e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
